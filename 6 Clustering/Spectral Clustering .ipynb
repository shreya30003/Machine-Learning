# %% [markdown]
# > # Spectral Clustering

# %%
import numpy as np
from sklearn.cluster import SpectralClustering, KMeans
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# %%
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
model = KMeans(n_clusters=2)
labels = model.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.show()

# %%
model = SpectralClustering(n_clusters=2, affinity='nearest_neighbors')
labels = model.fit_predict(X)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.show()

# %% [markdown]
# ### https://towardsdatascience.com/spectral-clustering-aba2640c0d5b#:~:text=Spectral%20clustering%20is%20a%20technique,non%20graph%2 - from scratch

# %% [markdown]
# ### http://blog.shriphani.com/2015/04/06/the-smallest-eigenvalues-of-a-graph-laplacian/ - why 2nd smallest eigen vector
